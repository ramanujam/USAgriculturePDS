# %%
import csv
import sqlite3
import pandas as pd
import math
# Use svg backend for better quality
import matplotlib
matplotlib.use("svg")
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 5.0)

# %% [markdown]
# ### Unix Area

# %%
# !ls -l ../data
# Out:
# total 326224
# -rw-r--r--@ 1 rohansingh  staff    151999 Apr 16 21:47 Analysis_Tableau.twb
# -rw-r--r--@ 1 rohansingh  staff     64517 Apr 16 22:30 Analysis_Tableau_AdCampaign.twb
# -rw-r--r--@ 1 rohansingh  staff  81131198 Mar  9 08:49 FeedGrains.csv
# -rw-r--r--  1 rohansingh  staff         0 Apr 12 01:01 FeedGrains.db
# -rw-r--r--@ 1 rohansingh  staff   4773458 Apr 12 00:18 FeedGrains.zip
# -rw-r--r--  1 rohansingh  staff  79233024 Apr 12 00:28 feedgrain.db
# -rw-r--r--@ 1 rohansingh  staff     37081 Apr 24 20:27 tax_per_operation_by_state_corn.csv

# %% [markdown]
# ### Config Variables

# %%
datadir = "../data/"
sqldb_grains = datadir + "feedgrain.db"

# %%
def connect_db(dbname=sqldb_grains):
    """ Returns a sqlite connection object.
    Inputs:
        dbname (str) : Name of the database to connect.
    Outputs:
        conn (sqlite connection object) : connection object for sqlite database.
    """
    conn = sqlite3.connect(dbname)
    conn.text_factory = str
    return conn

def get_cursor(conn):
    """ Returns a sqlite cursor object.
    Inputs:
        conn (sqlite connection object) : connection object for sqlite database.
    Outputs:
        cursor (sqlite cursor object) : cursor object for sqlite database.
    """
    return conn.cursor()

# %% [markdown]
# ### Preliminary Data Exploration

# %%
conn = connect_db()
cursor = get_cursor(conn)

# %%
res = cursor.execute("PRAGMA table_info(grains);")
for row in res:
    print(row)
# Out:
# (0, 'SC_Group_ID', 'TEXT', 0, None, 0)
# (1, 'SC_Group_Desc', 'TEXT', 0, None, 0)
# (2, 'SC_GroupCommod_ID', 'TEXT', 0, None, 0)
# (3, 'SC_GroupCommod_Desc', 'TEXT', 0, None, 0)
# (4, 'SC_Geography_ID', 'TEXT', 0, None, 0)
# (5, 'SortOrder', 'TEXT', 0, None, 0)
# (6, 'SC_GeographyIndented_Desc', 'TEXT', 0, None, 0)
# (7, 'SC_Commodity_ID', 'TEXT', 0, None, 0)
# (8, 'SC_Commodity_Desc', 'TEXT', 0, None, 0)
# (9, 'SC_Attribute_ID', 'TEXT', 0, None, 0)
# (10, 'SC_Attribute_Desc', 'TEXT', 0, None, 0)
# (11, 'SC_Unit_ID', 'TEXT', 0, None, 0)
# (12, 'SC_Unit_Desc', 'TEXT', 0, None, 0)
# (13, 'Year_ID', 'TEXT', 0, None, 0)
# (14, 'SC_Frequency_ID', 'TEXT', 0, None, 0)
# (15, 'SC_Frequency_Desc', 'TEXT', 0, None, 0)
# (16, 'Timeperiod_ID', 'TEXT', 0, None, 0)
# (17, 'Timeperiod_Desc', 'TEXT', 0, None, 0)
# (18, 'Amount', 'TEXT', 0, None, 0)

# %%
def view_distinct(col):
    res = cursor.execute("select distinct {} from grains".format(col))
    for row in res:
        print(row)
view_distinct('SC_Group_Desc')
# Out:
# ('Supply and use',)
# ('Prices',)
# ('Exports and imports',)
# ('Quantities fed',)
# ('Animal unit indexes',)
# ('Feed-price ratios',)
# ('Transportation',)

# %%
def get_data(crop, group):
    query = """
             select * from grains where SC_Commodity_Desc = '{0}' 
             and SC_Group_Desc = '{1}'
            """.format(crop, group)
    print(query)
    res = cursor.execute(query)
    list_corn_exp_imp = []
    for row in res:
        list_corn_exp_imp.append(row)
        
    df = pd.DataFrame(list_corn_exp_imp)
    return df

# %%
df_corn_exp_imp = get_data('Corn', 'Exports and imports')
df_corn_exp_imp
# Out:
#              select * from grains where SC_Commodity_Desc = 'Corn'
#              and SC_Group_Desc = 'Exports and imports'
#       0                    1   2     3   4        5   \
# 0      3  Exports and imports  12  Corn  31  134.000
# 1      3  Exports and imports  12  Corn  31  134.000
# 2      3  Exports and imports  12  Corn  31  134.000
# 3      3  Exports and imports  12  Corn  31  134.000
# 4      3  Exports and imports  12  Corn  31  134.000
# 5      3  Exports and imports  12  Corn  31  134.000
# 6      3  Exports and imports  12  Corn  31  134.000
# 7      3  Exports and imports  12  Corn  31  134.000
# 8      3  Exports and imports  12  Corn  31  134.000
# 9      3  Exports and imports  12  Corn  31  134.000
# 10     3  Exports and imports  12  Corn  31  134.000
# 11     3  Exports and imports  12  Corn  31  134.000
# 12     3  Exports and imports  12  Corn  31  134.000
# 13     3  Exports and imports  12  Corn  31  134.000
# 14     3  Exports and imports  12  Corn  31  134.000
# 15     3  Exports and imports  12  Corn  31  134.000
# 16     3  Exports and imports  12  Corn  31  134.000
# 17     3  Exports and imports  12  Corn  31  134.000
# 18     3  Exports and imports  12  Corn  31  134.000
# 19     3  Exports and imports  12  Corn  31  134.000
# 20     3  Exports and imports  12  Corn  31  134.000
# 21     3  Exports and imports  12  Corn  31  134.000
# 22     3  Exports and imports  12  Corn  31  134.000
# 23     3  Exports and imports  12  Corn  31  134.000
# 24     3  Exports and imports  12  Corn  31  134.000
# 25     3  Exports and imports  12  Corn  31  134.000
# 26     3  Exports and imports  12  Corn  31  134.000
# 27     3  Exports and imports  12  Corn  31  134.000
# 28     3  Exports and imports  12  Corn  31  134.000
# 29     3  Exports and imports  12  Corn  31  134.000
# ...   ..                  ...  ..   ...  ..      ...
# 62774  3  Exports and imports  12  Corn  25    1.000
# 62775  3  Exports and imports  12  Corn  25    1.000
# 62776  3  Exports and imports  12  Corn  25    1.000
# 62777  3  Exports and imports  12  Corn  25    1.000
# 62778  3  Exports and imports  12  Corn  25    1.000
# 62779  3  Exports and imports  12  Corn  25    1.000
# 62780  3  Exports and imports  12  Corn  25    1.000
# 62781  3  Exports and imports  12  Corn  25    1.000
# 62782  3  Exports and imports  12  Corn  25    1.000
# 62783  3  Exports and imports  12  Corn  25    1.000
# 62784  3  Exports and imports  12  Corn  25    1.000
# 62785  3  Exports and imports  12  Corn  25    1.000
# 62786  3  Exports and imports  12  Corn  25    1.000
# 62787  3  Exports and imports  12  Corn  25    1.000
# 62788  3  Exports and imports  12  Corn  25    1.000
# 62789  3  Exports and imports  12  Corn  25    1.000
# 62790  3  Exports and imports  12  Corn  25    1.000
# 62791  3  Exports and imports  12  Corn  25    1.000
# 62792  3  Exports and imports  12  Corn  25    1.000
# 62793  3  Exports and imports  12  Corn  25    1.000
# 62794  3  Exports and imports  12  Corn  25    1.000
# 62795  3  Exports and imports  12  Corn  25    1.000
# 62796  3  Exports and imports  12  Corn  25    1.000
# 62797  3  Exports and imports  12  Corn  25    1.000
# 62798  3  Exports and imports  12  Corn  25    1.000
# 62799  3  Exports and imports  12  Corn  25    1.000
# 62800  3  Exports and imports  12  Corn  25    1.000
# 62801  3  Exports and imports  12  Corn  25    1.000
# 62802  3  Exports and imports  12  Corn  25    1.000
# 62803  3  Exports and imports  12  Corn  25    1.000
#
#                              6  7     8   9   \
# 0          Asia and Middle East  2  Corn  24
# 1          Asia and Middle East  2  Corn  24
# 2          Asia and Middle East  2  Corn  24
# 3          Asia and Middle East  2  Corn  24
# 4          Asia and Middle East  2  Corn  24
# 5          Asia and Middle East  2  Corn  24
# 6          Asia and Middle East  2  Corn  24
# 7          Asia and Middle East  2  Corn  24
# 8          Asia and Middle East  2  Corn  24
# 9          Asia and Middle East  2  Corn  24
# 10         Asia and Middle East  2  Corn  24
# 11         Asia and Middle East  2  Corn  24
# 12         Asia and Middle East  2  Corn  24
# 13         Asia and Middle East  2  Corn  24
# 14         Asia and Middle East  2  Corn  24
# 15         Asia and Middle East  2  Corn  24
# 16         Asia and Middle East  2  Corn  24
# 17         Asia and Middle East  2  Corn  24
# 18         Asia and Middle East  2  Corn  24
# 19         Asia and Middle East  2  Corn  24
# 20         Asia and Middle East  2  Corn  24
# 21         Asia and Middle East  2  Corn  24
# 22         Asia and Middle East  2  Corn  24
# 23         Asia and Middle East  2  Corn  24
# 24         Asia and Middle East  2  Corn  24
# 25         Asia and Middle East  2  Corn  24
# 26         Asia and Middle East  2  Corn  24
# 27         Asia and Middle East  2  Corn  24
# 28         Asia and Middle East  2  Corn  24
# 29         Asia and Middle East  2  Corn  24
# ...                         ... ..   ...  ..
# 62774                     World  2  Corn  19
# 62775                     World  2  Corn  19
# 62776                     World  2  Corn  19
# 62777                     World  2  Corn  19
# 62778                     World  2  Corn  19
# 62779                     World  2  Corn  19
# 62780                     World  2  Corn  19
# 62781                     World  2  Corn  19
# 62782                     World  2  Corn  19
# 62783                     World  2  Corn  19
# 62784                     World  2  Corn  19
# 62785                     World  2  Corn  19
# 62786                     World  2  Corn  19
# 62787                     World  2  Corn  19
# 62788                     World  2  Corn  19
# 62789                     World  2  Corn  19
# 62790                     World  2  Corn  19
# 62791                     World  2  Corn  19
# 62792                     World  2  Corn  19
# 62793                     World  2  Corn  19
# 62794                     World  2  Corn  19
# 62795                     World  2  Corn  19
# 62796                     World  2  Corn  19
# 62797                     World  2  Corn  19
# 62798                     World  2  Corn  19
# 62799                     World  2  Corn  19
# 62800                     World  2  Corn  19
# 62801                     World  2  Corn  19
# 62802                     World  2  Corn  19
# 62803                     World  2  Corn  19
#
#                                                 10 11                 12  \
# 0      Exports, from U.S. to specified destination  7  1,000 metric tons
# 1      Exports, from U.S. to specified destination  7  1,000 metric tons
# 2      Exports, from U.S. to specified destination  7  1,000 metric tons
# 3      Exports, from U.S. to specified destination  7  1,000 metric tons
# 4      Exports, from U.S. to specified destination  7  1,000 metric tons
# 5      Exports, from U.S. to specified destination  7  1,000 metric tons
# 6      Exports, from U.S. to specified destination  7  1,000 metric tons
# 7      Exports, from U.S. to specified destination  7  1,000 metric tons
# 8      Exports, from U.S. to specified destination  7  1,000 metric tons
# 9      Exports, from U.S. to specified destination  7  1,000 metric tons
# 10     Exports, from U.S. to specified destination  7  1,000 metric tons
# 11     Exports, from U.S. to specified destination  7  1,000 metric tons
# 12     Exports, from U.S. to specified destination  7  1,000 metric tons
# 13     Exports, from U.S. to specified destination  7  1,000 metric tons
# 14     Exports, from U.S. to specified destination  7  1,000 metric tons
# 15     Exports, from U.S. to specified destination  7  1,000 metric tons
# 16     Exports, from U.S. to specified destination  7  1,000 metric tons
# 17     Exports, from U.S. to specified destination  7  1,000 metric tons
# 18     Exports, from U.S. to specified destination  7  1,000 metric tons
# 19     Exports, from U.S. to specified destination  7  1,000 metric tons
# 20     Exports, from U.S. to specified destination  7  1,000 metric tons
# 21     Exports, from U.S. to specified destination  7  1,000 metric tons
# 22     Exports, from U.S. to specified destination  7  1,000 metric tons
# 23     Exports, from U.S. to specified destination  7  1,000 metric tons
# 24     Exports, from U.S. to specified destination  7  1,000 metric tons
# 25     Exports, from U.S. to specified destination  7  1,000 metric tons
# 26     Exports, from U.S. to specified destination  7  1,000 metric tons
# 27     Exports, from U.S. to specified destination  7  1,000 metric tons
# 28     Exports, from U.S. to specified destination  7  1,000 metric tons
# 29     Exports, from U.S. to specified destination  7  1,000 metric tons
# ...                                            ... ..                ...
# 62774       Imports, to U.S. from specified source  7  1,000 metric tons
# 62775       Imports, to U.S. from specified source  7  1,000 metric tons
# 62776       Imports, to U.S. from specified source  7  1,000 metric tons
# 62777       Imports, to U.S. from specified source  7  1,000 metric tons
# 62778       Imports, to U.S. from specified source  7  1,000 metric tons
# 62779       Imports, to U.S. from specified source  7  1,000 metric tons
# 62780       Imports, to U.S. from specified source  7  1,000 metric tons
# 62781       Imports, to U.S. from specified source  7  1,000 metric tons
# 62782       Imports, to U.S. from specified source  7  1,000 metric tons
# 62783       Imports, to U.S. from specified source  7  1,000 metric tons
# 62784       Imports, to U.S. from specified source  7  1,000 metric tons
# 62785       Imports, to U.S. from specified source  7  1,000 metric tons
# 62786       Imports, to U.S. from specified source  7  1,000 metric tons
# 62787       Imports, to U.S. from specified source  7  1,000 metric tons
# 62788       Imports, to U.S. from specified source  7  1,000 metric tons
# 62789       Imports, to U.S. from specified source  7  1,000 metric tons
# 62790       Imports, to U.S. from specified source  7  1,000 metric tons
# 62791       Imports, to U.S. from specified source  7  1,000 metric tons
# 62792       Imports, to U.S. from specified source  7  1,000 metric tons
# 62793       Imports, to U.S. from specified source  7  1,000 metric tons
# 62794       Imports, to U.S. from specified source  7  1,000 metric tons
# 62795       Imports, to U.S. from specified source  7  1,000 metric tons
# 62796       Imports, to U.S. from specified source  7  1,000 metric tons
# 62797       Imports, to U.S. from specified source  7  1,000 metric tons
# 62798       Imports, to U.S. from specified source  7  1,000 metric tons
# 62799       Imports, to U.S. from specified source  7  1,000 metric tons
# 62800       Imports, to U.S. from specified source  7  1,000 metric tons
# 62801       Imports, to U.S. from specified source  7  1,000 metric tons
# 62802       Imports, to U.S. from specified source  7  1,000 metric tons
# 62803       Imports, to U.S. from specified source  7  1,000 metric tons
#
#          13 14       15  16          17                18
# 0      1989  1  Monthly   1         Jan  6.99358559189156
# 1      1989  1  Monthly   2         Feb  52.4610996409654
# 2      1989  1  Monthly   3         Mar  129.011765876798
# 3      1989  1  Monthly   4         Apr  35.0937994834521
# 4      1989  1  Monthly   5         May  6.20226705628551
# 5      1989  1  Monthly   6         Jun  8.08197312414798
# 6      1989  1  Monthly   7         Jul   5.3252630583532
# 7      1989  1  Monthly   8         Aug  25.2624757709665
# 8      1989  1  Monthly   9         Sep  58.9044032342166
# 9      1989  1  Monthly  10         Oct  10.8900453493984
# 10     1989  1  Monthly  11         Nov  4.79031746831901
# 11     1989  1  Monthly  12         Dec  16.0406017049852
# 12     1989  3   Annual  31  MY Sep-Aug  159.319617936662
# 13     1990  1  Monthly   1         Jan  11.5296755891588
# 14     1990  1  Monthly   2         Feb  5.22119319743814
# 15     1990  1  Monthly   3         Mar  8.78240517403629
# 16     1990  1  Monthly   4         Apr  5.26184338291935
# 17     1990  1  Monthly   5         May  15.8694724757778
# 18     1990  1  Monthly   6         Jun  8.46647696045988
# 19     1990  1  Monthly   7         Jul   5.4149974733239
# 20     1990  1  Monthly   8         Aug   8.1481859266289
# 21     1990  1  Monthly   9         Sep    3.565301401445
# 22     1990  1  Monthly  10         Oct   4.2790299708406
# 23     1990  1  Monthly  11         Nov  5.74405336977174
# 24     1990  1  Monthly  12         Dec  4.45692076522501
# 25     1990  3   Annual  31  MY Sep-Aug  107.630095937078
# 26     1991  1  Monthly   1         Jan  9.77027476650398
# 27     1991  1  Monthly   2         Feb  5.44183530761123
# 28     1991  1  Monthly   3         Mar  6.47975361865277
# 29     1991  1  Monthly   4         Apr  14.1283366721589
# ...     ... ..      ...  ..         ...               ...
# 62774  2015  1  Monthly  11         Nov      286.99422897
# 62775  2015  1  Monthly  12         Dec      263.43590744
# 62776  2015  3   Annual  31  MY Sep-Aug     2679.94322975
# 62777  2016  1  Monthly   1         Jan      259.90257294
# 62778  2016  1  Monthly   2         Feb      181.83974777
# 62779  2016  1  Monthly   3         Mar      289.09620711
# 62780  2016  1  Monthly   4         Apr      254.93244688
# 62781  2016  1  Monthly   5         May      221.05079265
# 62782  2016  1  Monthly   6         Jun      251.29840134
# 62783  2016  1  Monthly   7         Jul      162.45036187
# 62784  2016  1  Monthly   8         Aug      238.82217047
# 62785  2016  1  Monthly   9         Sep      200.30145622
# 62786  2016  1  Monthly  10         Oct      143.71505387
# 62787  2016  1  Monthly  11         Nov       250.9769904
# 62788  2016  1  Monthly  12         Dec       153.6897905
# 62789  2016  3   Annual  31  MY Sep-Aug     2427.71427343
# 62790  2017  1  Monthly   1         Jan       237.1110826
# 62791  2017  1  Monthly   2         Feb      145.87761965
# 62792  2017  1  Monthly   3         Mar       217.3537694
# 62793  2017  1  Monthly   4         Apr      226.20030347
# 62794  2017  1  Monthly   5         May      235.69768755
# 62795  2017  1  Monthly   6         Jun      213.65230868
# 62796  2017  1  Monthly   7         Jul      228.01532106
# 62797  2017  1  Monthly   8         Aug      175.12289003
# 62798  2017  1  Monthly   9         Sep      232.39118657
# 62799  2017  1  Monthly  10         Oct      176.87811588
# 62800  2017  1  Monthly  11         Nov      166.92908889
# 62801  2017  1  Monthly  12         Dec      118.73146406
# 62802  2017  3   Annual  31  MY Sep-Aug      905.02318447
# 62803  2018  1  Monthly   1         Jan      210.09332907
#
# [62804 rows x 19 columns]

# %%
df_corn_exp_imp = df_corn_exp_imp[[6, 8, 10, 12, 13, 15, 17, 18]]

# %%
df_corn_exp_imp.columns = ['slno', 'destination', 'type','unit', 'year', 'frequency', 'month', 'amount']
df_corn_exp_imp
df_corn_exports = df_corn_exp_imp[df_corn_exp_imp['type']=="Exports, from U.S. to specified destination"]
df_corn_exports.loc[:,('amount')] = df_corn_exports.loc[:,('amount')].astype(float)
# df_corn_exp_imp['destination'].value_counts()
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
df_corn_exp_by_country_region = df_corn_exports.groupby('slno')['amount'].sum().reset_index()
df_corn_exp_by_country_region = df_corn_exp_by_country_region[df_corn_exp_by_country_region['slno'] != 'World']
df_corn_exp_by_country_region = df_corn_exp_by_country_region.sort_values(by='amount')
df_corn_exp_by_country_region
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d1a9fffcb0d7> in <module>()
#       1 df_corn_exp_by_country_region = df_corn_exports.groupby('slno')['amount'].sum().reset_index()
#       2 df_corn_exp_by_country_region = df_corn_exp_by_country_region[df_corn_exp_by_country_region['slno'] != 'World']
# ----> 3 df_corn_exp_by_country_region = df_corn_exp_by_country_region.sort_values(by='amount', reverse=True)
#       4 df_corn_exp_by_country_region
#
# TypeError: sort_values() got an unexpected keyword argument 'reverse'

# %%
plt.bar(df_corn_exp_by_country_region['slno'], df_corn_exp_by_country_region['amount'])
# Out:
# <BarContainer object of 240 artists>

# %%
df_asiaME = df_corn_exp_imp[df_corn_exp_imp['exportedTo'] == "Asia and Middle East"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'exportedTo'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-9a7674ddf9e5> in <module>()
# ----> 1 df_asiaME = df_corn_exp_imp[df_corn_exp_imp['exportedTo'] == "Asia and Middle East"]
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'exportedTo'

# %%
df_asiaME_yearly = df_asiaME[df_asiaME['frequency'] == "Annual"]

# %%
df_world_yearly = df_world_yearly[['year', 'amount']]
df_world_yearly['year'] = df_world_yearly['year'].apply(int)
df_world_yearly['amount'] = df_world_yearly['amount'].apply(float)
df_world_yearly['amount'] = df_world_yearly['amount']/100000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-121e43a98963> in <module>()
# ----> 1 df_world_yearly = df_world_yearly[['year', 'amount']]
#       2 df_world_yearly['year'] = df_world_yearly['year'].apply(int)
#       3 df_world_yearly['amount'] = df_world_yearly['amount'].apply(float)
#       4 df_world_yearly['amount'] = df_world_yearly['amount']/100000
#
# NameError: name 'df_world_yearly' is not defined

# %%
df_asiaME_yearly = df_asiaME_yearly[['year', 'amount']]
df_asiaME_yearly['year'] = df_asiaME_yearly['year'].apply(int)
df_asiaME_yearly['amount'] = df_asiaME_yearly['amount'].apply(float)
df_asiaME_yearly['amount'] = df_asiaME_yearly['amount']/100000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c509ff5f064b> in <module>()
# ----> 1 df_asiaME_yearly = df_asiaME_yearly[['year', 'amount']]
#       2 df_asiaME_yearly['year'] = df_asiaME_yearly['year'].apply(int)
#       3 df_asiaME_yearly['amount'] = df_asiaME_yearly['amount'].apply(float)
#       4 df_asiaME_yearly['amount'] = df_asiaME_yearly['amount']/100000
#
# NameError: name 'df_asiaME_yearly' is not defined

# %%
df_world_yearly = df_world_yearly.iloc[:29]
df_asiaME_yearly = df_asiaME_yearly.iloc[:29]
df_asiaME_imp_yearly = df_asiaME_yearly.iloc[29:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f09f681f1ba2> in <module>()
# ----> 1 df_world_yearly = df_world_yearly.iloc[:29]
#       2 df_asiaME_yearly = df_asiaME_yearly.iloc[:29]
#       3 df_asiaME_imp_yearly = df_asiaME_yearly.iloc[29:]
#
# NameError: name 'df_world_yearly' is not defined

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
list_lines = []
list_lines, = ax.plot(df_world_yearly['year'], df_world_yearly['amount'])
ax.plot(df_asiaME_yearly['year'], df_asiaME_yearly['amount'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-e8dfc720bd33> in <module>()
#       2 ax = fig.add_subplot(111)
#       3 list_lines = []
# ----> 4 list_lines, = ax.plot(df_world_yearly['year'], df_world_yearly['amount'])
#       5 ax.plot(df_asiaME_yearly['year'], df_asiaME_yearly['amount'])
#
# NameError: name 'df_world_yearly' is not defined

# %%
df_asiaME_yearly
# Out:
# Empty DataFrame
# Columns: [year, amount]
# Index: []
